# %%
#!pip3 install langchain_community
#!pip3 install langchain_openai
#pip3 install bert_score

# %%
import pandas as pd
import openai
from dotenv import load_dotenv
import os
import ast
from openai import AzureOpenAI
import faiss
import numpy as np
import json
from bert_score import score

# %% [markdown]
# ### Load Enviroment files

# %%
# Load environment variables
load_dotenv()
# Out:
# Python-dotenv could not parse statement starting at line 10
# Python-dotenv could not parse statement starting at line 11
# Python-dotenv could not parse statement starting at line 12
# Python-dotenv could not parse statement starting at line 13
# Python-dotenv could not parse statement starting at line 14
# Python-dotenv could not parse statement starting at line 15
# Python-dotenv could not parse statement starting at line 16
# Python-dotenv could not parse statement starting at line 17
# Python-dotenv could not parse statement starting at line 18
# Python-dotenv could not parse statement starting at line 19
# Python-dotenv could not parse statement starting at line 20
# True

# %%
openai.api_type = "azure"
openai.api_key = os.getenv("OPENAI_API_KEY")
openai.api_base = os.getenv("OPENAI_API_BASE")
openai.api_version = os.getenv("OPENAI_API_VERSION")
openai_deployment = "sdgi-gpt-35-turbo-16k"
neo4j_pass = os.getenv("NEO4JPASS")

# %%
# OpenAI API configuration
#openai.api_type = "azure"
#openai.api_key = os.getenv("api_key_azure")
#openai.api_base = os.getenv("AZURE_OPENAI_ENDPOINT")
#openai.api_version = os.getenv("api_version")
#openai_deployment = "sdgi-gpt-35-turbo-16k"


client = AzureOpenAI(
  api_key = os.getenv("OPENAI_API_KEY"),  
  api_version = os.getenv("OPENAI_API_VERSION"),
  azure_endpoint =os.getenv("AZURE_OPENAI_ENDPOINT") 
)

embedding_model = os.getenv("USER_QUERY_EMBEDDING_ENGINE") 

# print(openai.api_key)
# print(openai.api_base)
# print(openai.api_version)

# %%
with open("queries.json") as f:
    data = f.read()
    query_list = json.loads(data)

# %% [markdown]
# <h3>globals</h3>

# %%
test_query = query_list['query1']

# %% [markdown]
# <h3> helper functions </h3>

# %%
# use this function to make simple openAI Calls
def callOpenAI(prompt):  
    response_entities = openai.chat.completions.create(
                    model=openai_deployment,
                    temperature=0,
                    messages=[
                        {"role": "user", "content": prompt},
                    ]
                )
    response = response_entities.choices[0].message.content
    return response

# %% [markdown]
# <h3> processing modules </h3>

# %%
def extractEntitiesFromQuery(user_query):
    prompt = f"""
    Extract entities from the following user query: \"{user_query}\" and return output in array format.
    
    -Entities should be directly related to the domain or topic of interest. They should represent important concepts that contribute to the understanding of the subject matter.
    -Each entity in the knowledge graph should be distinct and have a unique identifier. This ensures clarity and avoids ambiguity when establishing relationships between entities.
    -You Must return output in array format e.g  ['entity1','entity2'] !!!
    -Avoid adding new lines or breaking spaces to your output. Array should be single dimension and single line !!!
    """
    entity_str = callOpenAI(prompt)   
    return entity_str

# %%
entity_str = extractEntitiesFromQuery(test_query)
# Convert the string representation of the list to an actual list
entity_list = ast.literal_eval(entity_str)

type(entity_list)
# Out:
# list

# %% [markdown]
# # KG module

# %%
from py2neo import Graph, Node, Relationship
graph = Graph(uri = 'bolt://localhost:7687',user='neo4j',password=neo4j_pass)

# %%
def search_entities_with_relations(label, name):
    """
    Search for nodes by label and name, including all their relationships and connected nodes.

    :param label: The label of the nodes to search.
    :param name: The name property value of the nodes to search.
    :return: A list of dictionaries, each containing a node and its relationships and connected nodes.
    """
    # Match nodes and their relationships, case-insensitive search
    query = f"""
    MATCH (n:`{label}`)-[r]-(m)
    WHERE toLower(n.name) = toLower($name) OR toLower(n.acronym) = toLower($name)
    RETURN n, collect(r) as relations, collect(m) as connectedNodes
    """
    results = graph.run(query, name=name).data()
    
    # Construct a comprehensive view for each node with its relationships and connected nodes
    entities_with_relations = []
    for record in results:
        entity_info = {
            'node': record['n'],
            'relationships': record['relations'],
            'connected_nodes': record['connectedNodes']
        }
        entities_with_relations.append(entity_info)

    return entities_with_relations

# %%
def separate_entities_and_relationships(relationships):
    """
    Separates entities and relationships from Neo4j query output into distinct structures,
    ensuring no duplicate entities are included.

    :param relationships: A list of Relationship objects from a Neo4j query.
    :return: A tuple containing two lists: one for unique entities and another for relationships.
    """
    # Using a dictionary to ensure unique entities based on a combination of name and category
    entities_dict = {}
    rels = []

    for rel in relationships:
        # Process both the source and target nodes for each relationship
        for node in [rel.start_node, rel.end_node]:
            # Define a unique identifier for each entity
            entity_id = f"{node['name']}_{node['category']}"
            
            # If the entity is not already in the dictionary, add it
            if entity_id not in entities_dict:
                entities_dict[entity_id] = {
                    'name': node['name'],
                    'category': node.get('category', 'N/A'),
                    #'summary': node.get('summary', 'N/A'),
                    'acronym': node.get('acronym', 'N/A'),
                }

        # Add relationship information
        rels.append({
            'subject': rel.start_node['name'],
            'object': rel.end_node['name'],
            'relationship_type': rel.__class__.__name__,
            'description': rel.get('description', 'N/A'),
        })

    # Convert the entities dictionary to a list to remove the unique identifier layer
    entities_list = list(entities_dict.values())

    return entities_list, rels

# %%
def search_embeddings(user_query):
    df = pd.read_pickle('../models/df_embed_EN.pkl')
    df_filtered = df
    length = len(df_filtered.head())
    filtered_embeddings_arrays = np.array(list(df_filtered['Embedding']))
    index = faiss.IndexFlatIP(filtered_embeddings_arrays.shape[1]) 
    index.add(filtered_embeddings_arrays)
    
    user_query_embedding = client.embeddings.create( 
        input=user_query ,model= embedding_model
    ).data[0].embedding
    
    k = min(5, length)
    distances, indices = index.search(np.array([user_query_embedding]), k)
    return df_filtered, distances, indices

# %%
def get_answer(user_question, content):
    system_prompt = "You are a system that answers user questions based on excerpts from PDF documents provided for context. Only answer if the answer can be found in the provided context. Do not make up the answer; if you cannot find the answer, say so."
    messages = [
        {'role': 'system', 'content': system_prompt},
        {'role': 'user', 'content': user_question},
        {'role': 'user', 'content': content},
    ]
    response_entities = openai.chat.completions.create(
                    model=openai_deployment,
                    temperature=0.2,
                    messages=messages
                )
    response = response_entities.choices[0].message.content
    return response

# %%
def map_to_structure(qs):
    result_dict = {}

    # Extract the DataFrame from the tuple
    dataframe = qs[0]

    # Counter to limit the loop to 10 iterations
    count = 0

    for index, row in dataframe.iterrows():
        # Define a unique identifier for each document, you can customize this based on your data
        document_id = f"doc-{index + 1}"
        # Handle NaN in content by using fillna
        content = row["Content"]
        content = ' '.join(row["Content"].split()[:160])
        # Create a dictionary for each document
        document_info = {
            "title": row["Document Title"],
            "extract": content or "",  # You may need to adjust this based on your column names
            "category": row["Category"],
            "link": row["Link"],
            "thumbnail": ''
        }
        # print(document_info)
        # Add the document to the result dictionary
        result_dict[document_id] = document_info

        # Increment the counter
        count += 1

        # # Break out of the loop if the counter reaches top 10
        if count == 10:
            break

    return result_dict

# %%
## module to get data for specific indicators which are identified is relevant to the user query

def indicatorsModule(user_query): #lower priority
    
    # find relevant indicators based on uesr query and extract values
    indicators_dict={
        "indicator-id-1":"value from indicator-id-1",
        "indicator-id-2":"value from indicator-id-2"
    }#temp
    
    return indicators_dict

## module to extract text from documents and return the text and document codes

def semanticSearchModule(user_query):
    qs = search_embeddings(user_query) #df, distances, indices
    result_structure = map_to_structure(qs)
    return result_structure

# %%
relations_list = []

# %%
for item in entity_list:
    entities_with_relations = search_entities_with_relations('Entity', item)
    
    for entity_info in entities_with_relations:
        relations_list.extend(entity_info['relationships'])
        #print("Connected Nodes:", entity_info['connected_nodes'])

# Assuming 'relationships' is your list of Relationship objects from the query
entities, relationships = separate_entities_and_relationships(relations_list)

# %%
relationships
# Out:
# [{'subject': 'Gender Development Index',
#   'object': 'Albania',
#   'relationship_type': 'focuses_on',
#   'description': 'Albania has a Gender Development Index of 0.967.'},
#  {'subject': 'United Nations Development Programme',
#   'object': 'United Nations agencies',
#   'relationship_type': 'partners_with',
#   'description': 'UNDP partners with United Nations agencies to achieve its goals.'},
#  {'subject': 'United Nations',
#   'object': 'United Nations Development Programme',
#   'relationship_type': 'partners_with',
#   'description': 'Building on previous successes, UNDP will work with civil society and the government to improve human capacities and data systems for performance, transparency and planning. UNDP will work on the quality of services and rule of law, in close collaboration with United Nations partners.'},
#  {'subject': 'United Nations Population Fund',
#   'object': 'United Nations Development Programme',
#   'relationship_type': 'partners_with',
#   'description': 'The United Nations Population Fund partners with the United Nations Development Programme.'},
#  {'subject': 'United Nations Development Programme',
#   'object': 'Government',
#   'relationship_type': 'partners_with',
#   'description': 'UNDP will assist the Government in driving policies and actions that focus on prevention and reduction of disaster-related risks, increasing resilience of infrastructures, ecosystems and society, and enabling adaptive capacities, all as a means to reduce the long-term vulnerability of the population and protect development investments, particularly in at-risk areas.'},
#  {'subject': 'United Nations Development Programme',
#   'object': 'United Nations',
#   'relationship_type': 'partners_with',
#   'description': 'UNDP will participate in joint Government–United Nations coordination mechanisms.'},
#  {'subject': 'United Nations Development Programme',
#   'object': 'Sustainable Development Goals',
#   'relationship_type': 'partners_with',
#   'description': 'UNDP has established multi-stakeholder partnerships on priorities for the Sustainable Development Goals.'},
#  {'subject': 'United Nations Office for Project Services',
#   'object': 'United Nations Development Programme',
#   'relationship_type': 'partners_with',
#   'description': 'The United Nations Office for Project Services partners with the United Nations Development Programme.'},
#  {'subject': 'United Nations Development Programme',
#   'object': 'United Nations Sustainable Development Cooperation Framework',
#   'relationship_type': 'focuses_on',
#   'description': 'The United Nations Development Programme focuses on the United Nations Sustainable Development Cooperation Framework.'},
#  {'subject': 'United Nations Development Programme',
#   'object': 'National Statistical Office',
#   'relationship_type': 'contributes_to',
#   'description': 'UNDP will employ national monitoring systems, official statistical data and reports from line ministries, development partners and research institutions to measure its contribution to national results.'},
#  {'subject': 'United Nations Development Programme',
#   'object': 'Sustainable Development Goals',
#   'relationship_type': 'contributes_to',
#   'description': 'The results framework is aligned with indicators related to European Union accession, the NSDI and the national indicator framework for the Sustainable Development Goals.'},
#  {'subject': 'European Union',
#   'object': 'United Nations Development Programme',
#   'relationship_type': 'contributes_to',
#   'description': 'The European Union will contribute to the priorities of UNDP.'},
#  {'subject': 'United Nations Development Programme',
#   'object': 'Albania',
#   'relationship_type': 'contributes_to',
#   'description': 'Risks will be managed through coordination and partnerships; advocacy and policy dialogue; regular monitoring of risks, project and results; and updating of contingency plans for the country office and national emergencies.'},
#  {'subject': 'Albania',
#   'object': 'United Nations Development Programme',
#   'relationship_type': 'contributes_to',
#   'description': 'Albania will contribute to the priorities of UNDP.'},
#  {'subject': 'United Nations Development Programme',
#   'object': 'European Union',
#   'relationship_type': 'supports',
#   'description': 'The monitoring and evaluation plan will be implemented following endorsement of the CPD by the Executive Board.'},
#  {'subject': 'United Nations Development Programme',
#   'object': 'National Statistical Office',
#   'relationship_type': 'monitors',
#   'description': 'UNDP will employ national monitoring systems, official statistical data and reports from line ministries, development partners and research institutions to measure its contribution to national results.'},
#  {'subject': 'United Nations Development Programme',
#   'object': 'Sustainable Development Goals',
#   'relationship_type': 'monitors',
#   'description': 'The results framework is aligned with indicators related to European Union accession, the NSDI and the national indicator framework for the Sustainable Development Goals.'},
#  {'subject': 'United Nations Development Programme',
#   'object': 'Executive Board',
#   'relationship_type': 'monitors',
#   'description': 'The monitoring and evaluation plan will be implemented following endorsement of the CPD by the Executive Board.'},
#  {'subject': 'United Nations Development Programme',
#   'object': 'Government',
#   'relationship_type': 'supports',
#   'description': 'UNDP will continue to support the Government to address structural and systemic barriers to gender equality and women’s empowerment in policy formulation and implementation.'},
#  {'subject': 'United Nations Development Programme',
#   'object': 'People’s Advocate',
#   'relationship_type': 'supports',
#   'description': 'UNDP will continue to support the People’s Advocate.'},
#  {'subject': 'People’s Advocate',
#   'object': 'United Nations Development Programme',
#   'relationship_type': 'supports',
#   'description': 'UNDP will continue to support the People’s Advocate.'},
#  {'subject': 'United Nations Development Programme',
#   'object': 'National Public Administration Reform Strategy',
#   'relationship_type': 'supports',
#   'description': 'UNDP will broaden partnerships for a stronger good governance framework, in line with the National Public Administration Reform Strategy.'},
#  {'subject': 'Albanian Government',
#   'object': 'Albania',
#   'relationship_type': 'supports',
#   'description': 'The Albanian Government supports the energy sector in Albania.'},
#  {'subject': 'Albania',
#   'object': 'Strategy',
#   'relationship_type': 'supports',
#   'description': 'The share of import in percentage of the Gross Inland Consumption is high, thus affecting the security of supply.'},
#  {'subject': 'Albania',
#   'object': 'Gross Inland Consumption',
#   'relationship_type': 'supports',
#   'description': 'In terms of Gross inland consumption (to be confirmed) 2019, the Albanian energy system has been dominated and still continues to be dominated by oil by products for transport use (appr. 53.3%), followed by electricity produced from hydropower (appr. 28.17%), and in the third place is biomass (fuelwood, appr. 6.8%) used for heating, cooking and domestic hot water.'},
#  {'subject': 'Albania',
#   'object': 'Ministry of Infrastructure and Energy',
#   'relationship_type': 'monitors',
#   'description': 'The Ministry of Infrastructure and Energy monitors the oil and gas sector in Albania.'},
#  {'subject': 'Kosovo',
#   'object': 'Albania',
#   'relationship_type': 'partners_with',
#   'description': 'Albanian Transmission System Operator and Kosovo’s power transmission system operator KOSTT have signed an agreement to set up a common energy market as two neighboring countries'},
#  {'subject': 'World Trade Organization',
#   'object': 'Albania',
#   'relationship_type': 'partners_with',
#   'description': 'Albania is a member of the World Trade Organization and can, therefore, access easily the EU market.'},
#  {'subject': 'Austria',
#   'object': 'Albania',
#   'relationship_type': 'partners_with',
#   'description': 'Austria and Albania have a partnership.'},
#  {'subject': 'Germany',
#   'object': 'Albania',
#   'relationship_type': 'partners_with',
#   'description': 'Germany and Albania have a partnership.'},
#  {'subject': 'Council of Ministers',
#   'object': 'Albania',
#   'relationship_type': 'partners_with',
#   'description': 'The Council of Ministers may enter into agreements with Albania for mutual recognition of guarantees of origin for renewable energy.'},
#  {'subject': 'Serbia',
#   'object': 'Albania',
#   'relationship_type': 'partners_with',
#   'description': 'Serbia partners with Albania in transport infrastructure coordination'},
#  {'subject': 'Montenegro',
#   'object': 'Albania',
#   'relationship_type': 'partners_with',
#   'description': 'Montenegro partners with Albania in transport infrastructure coordination'},
#  {'subject': 'Bosnia and Herzegovina',
#   'object': 'Albania',
#   'relationship_type': 'partners_with',
#   'description': 'Bosnia and Herzegovina partners with Albania in transport infrastructure coordination'},
#  {'subject': 'National Territory Council',
#   'object': 'Albania',
#   'relationship_type': 'partners_with',
#   'description': 'The construction of gas interconnections in Albania is elaborated in details in the Gas Master Plan (GMP) for Albania adopted by the DCM No 87 of 14.02.2018 “On the approval of the Plan for the development of the natural gas sector in Albania and the identification of the priority projects” as well as by the National Territory Council (NTC) with its Decision No 2 of 26 July 2018.'},
#  {'subject': 'Greece',
#   'object': 'Albania',
#   'relationship_type': 'partners_with',
#   'description': 'Greece partners with Albania in the market integration option for the Ukraine South corridor.'},
#  {'subject': 'Croatia',
#   'object': 'Albania',
#   'relationship_type': 'partners_with',
#   'description': 'Croatia partners with Albania in the market integration option for the Ukraine South corridor.'},
#  {'subject': 'Ionian Adriatic Pipeline',
#   'object': 'Albania',
#   'relationship_type': 'partners_with',
#   'description': 'The project will make Albania the gateway for Caspian gas to enter the West Balkans.'},
#  {'subject': 'Ukraine South Integration corridor',
#   'object': 'Albania',
#   'relationship_type': 'partners_with',
#   'description': 'Albania can take advantage of its geographical location within the Western Balkan region and become part of a more robust gas market.'},
#  {'subject': 'Adriatic Integration Corridor',
#   'object': 'Albania',
#   'relationship_type': 'partners_with',
#   'description': 'Albania can take advantage of its geographical location within the Western Balkan region and become a key player in the development and deployment of a regional gas transmission network for a sub-regional market.'},
#  {'subject': 'Albania',
#   'object': 'European Bank for Reconstruction and Development',
#   'relationship_type': 'partners_with',
#   'description': 'Albania partners with EBRD'},
#  {'subject': 'Albania',
#   'object': 'Municipality of Tirana',
#   'relationship_type': 'partners_with',
#   'description': 'Albania partners with the Municipality of Tirana for the implementation of STO.'},
#  {'subject': 'Albania',
#   'object': 'European Union',
#   'relationship_type': 'partners_with',
#   'description': 'With Albania positioning itself as a unifying actor for regional cooperation, security and stability, and taking the initial steps to establish the national disaster risk management system as a requirement to join the European Union Civil Protection Mechanism, UNDP will continue to promote knowledge-sharing and relevant practices across the subregion.'},
#  {'subject': 'Albania',
#   'object': 'European Network of Transmission System Operators for Gas',
#   'relationship_type': 'partners_with',
#   'description': 'Albania collaborates with ENTSO-G in the European energy market'},
#  {'subject': 'Albania',
#   'object': 'Serbia',
#   'relationship_type': 'partners_with',
#   'description': 'Albania partners with Serbia in transport infrastructure coordination'},
#  {'subject': 'Albania',
#   'object': 'Montenegro',
#   'relationship_type': 'partners_with',
#   'description': 'Albania partners with Montenegro in transport infrastructure coordination'},
#  {'subject': 'Albania',
#   'object': 'Bosnia and Herzegovina',
#   'relationship_type': 'partners_with',
#   'description': 'Albania partners with Bosnia and Herzegovina in transport infrastructure coordination'},
#  {'subject': 'Albania',
#   'object': 'Romania',
#   'relationship_type': 'partners_with',
#   'description': 'Albania partners with Romania in the market integration option for the Ukraine South corridor.'},
#  {'subject': 'Albania',
#   'object': 'Bulgaria',
#   'relationship_type': 'partners_with',
#   'description': 'Albania partners with Bulgaria in the market integration option for the Ukraine South corridor.'},
#  {'subject': 'Albania',
#   'object': 'Moldova',
#   'relationship_type': 'partners_with',
#   'description': 'Albania partners with Moldova in the market integration option for the Ukraine South corridor.'},
#  {'subject': 'Albania',
#   'object': 'Ukraine',
#   'relationship_type': 'partners_with',
#   'description': 'Albania partners with Ukraine in the market integration option for the Ukraine South corridor.'},
#  {'subject': 'Albania',
#   'object': 'Macedonia',
#   'relationship_type': 'partners_with',
#   'description': 'Albania partners with Macedonia in the market integration option for the Ukraine South corridor.'},
#  {'subject': 'Albania',
#   'object': 'United Nations Framework Convention on Climate Change',
#   'relationship_type': 'partners_with',
#   'description': 'Albania partners with United Nations Framework Convention on Climate Change'},
#  {'subject': 'Albania',
#   'object': 'International Finance Corporation',
#   'relationship_type': 'partners_with',
#   'description': 'Albania partners with IFC'},
#  {'subject': 'Albania',
#   'object': 'Croatia',
#   'relationship_type': 'partners_with',
#   'description': 'Albania partners with Croatia in the market integration option for the Ukraine South corridor.'},
#  {'subject': 'Albania',
#   'object': 'United States Agency for International Development',
#   'relationship_type': 'partners_with',
#   'description': 'Albania partners with USAID'},
#  {'subject': 'Albania',
#   'object': 'European Union',
#   'relationship_type': 'partners_with',
#   'description': 'Albania partners with the European Union.'},
#  {'subject': 'Albania',
#   'object': 'Ministry of Energy and Industry',
#   'relationship_type': 'partners_with',
#   'description': 'N/A'},
#  {'subject': 'Albania',
#   'object': 'Kosovo',
#   'relationship_type': 'partners_with',
#   'description': 'Albanian Transmission System Operator and Kosovo’s power transmission system operator KOSTT have signed an agreement to set up a common energy market as two neighboring countries'},
#  {'subject': 'Albania',
#   'object': 'Albanian Electricity Distribution System Operator',
#   'relationship_type': 'partners_with',
#   'description': 'OShEE is a single legal entity that includes both the Distribution System Operator (“DSO”) and the Universal Service Provider.'},
#  {'subject': 'Albania',
#   'object': 'Greece',
#   'relationship_type': 'partners_with',
#   'description': 'Albania partners with Greece in the market integration option for the Ukraine South corridor.'},
#  {'subject': 'Albania',
#   'object': 'Italy',
#   'relationship_type': 'partners_with',
#   'description': 'Private investors have also shown interest to build an underwater cable system linking Albania to Italy.'},
#  {'subject': 'Albania',
#   'object': 'Trans Adriatic Pipeline AG',
#   'relationship_type': 'partners_with',
#   'description': 'ALBGAZ Company includes the possibility of cooperation with foreign companies currently operating in Albania, such as TAP AG, but also with other companies that may be present in the future.'},
#  {'subject': 'Ballsh',
#   'object': 'Albania',
#   'relationship_type': 'in',
#   'description': "Albania's refinery at Ballsh faces serious challenges to its continued commercially viable operation as crude oil refinery."},
#  {'subject': 'Bistrica',
#   'object': 'Albania',
#   'relationship_type': 'in',
#   'description': 'The river Bistrica is located in Albania.'},
#  {'subject': 'Devoll',
#   'object': 'Albania',
#   'relationship_type': 'in',
#   'description': 'The river Devoll is located in Albania.'},
#  {'subject': 'Vjosa',
#   'object': 'Albania',
#   'relationship_type': 'in',
#   'description': 'The river Vjosa is located in Albania.'},
#  {'subject': 'Mat',
#   'object': 'Albania',
#   'relationship_type': 'in',
#   'description': 'The river Mat is located in Albania.'},
#  {'subject': 'Devoll River',
#   'object': 'Albania',
#   'relationship_type': 'in',
#   'description': 'Devoll River is located in Albania.'},
#  {'subject': 'North Macedonia',
#   'object': 'Albania',
#   'relationship_type': 'in',
#   'description': 'North Macedonia has interconnectivity infrastructure with Albania'},
#  {'subject': 'Fier',
#   'object': 'Albania',
#   'relationship_type': 'in',
#   'description': 'Fier is a location in Albania'},
#  {'subject': 'Dumre',
#   'object': 'Albania',
#   'relationship_type': 'in',
#   'description': 'Albania intends to develop an underground natural gas storage site in Dumre, near Elbasan'},
#  {'subject': 'Fier Compressor Station',
#   'object': 'Albania',
#   'relationship_type': 'in',
#   'description': 'The construction of the pipeline that will link the TAP project near the Fier Compressor Station area to the Vlora TPP and the entire Vlora region, will make it possible to restore the Vlora TPP by using natural gas'},
#  {'subject': 'Tirana',
#   'object': 'Albania',
#   'relationship_type': 'in',
#   'description': 'Tirana is a location in Albania.'},
#  {'subject': 'Durres',
#   'object': 'Albania',
#   'relationship_type': 'in',
#   'description': 'Durres is a location in Albania.'},
#  {'subject': 'Porto Romano',
#   'object': 'Albania',
#   'relationship_type': 'in',
#   'description': 'The biodiesel plant in Porto Romano is located in Albania.'},
#  {'subject': 'Elbasan',
#   'object': 'Albania',
#   'relationship_type': 'in',
#   'description': 'Albania intends to develop an underground natural gas storage site in Dumre, near Elbasan'},
#  {'subject': 'Kosovo',
#   'object': 'Albania',
#   'relationship_type': 'in',
#   'description': 'The Master Plan of Natural Gas for Albania was approved by DCM No. 87 of 14.02.2018 and aims to develop a sustainable natural gas system that enables a balanced contribution to the energy system, ensuring gas supply through competition and environmental protection.'},
#  {'subject': 'Tirana2',
#   'object': 'Albania',
#   'relationship_type': 'in',
#   'description': 'The 400KV interconnection line between Tirana2 (Albania) and Kosova B (Kosovo) should increase the electrical energy exchange potential between Albania and Kosovo up to 600 MW.'},
#  {'subject': 'Kosova B',
#   'object': 'Albania',
#   'relationship_type': 'in',
#   'description': 'The 400KV interconnection line between Tirana2 (Albania) and Kosova B (Kosovo) should increase the electrical energy exchange potential between Albania and Kosovo up to 600 MW.'},
#  {'subject': 'Albania',
#   'object': 'New York',
#   'relationship_type': 'in',
#   'description': 'Albania signed the Paris Agreement on the 22nd of April 2016 in New York'},
#  {'subject': 'Albania',
#   'object': 'Macedonian',
#   'relationship_type': 'in',
#   'description': 'In addition, a Memorandum of Understanding is signed between the Albanian and Macedonian transmission system operators for the construction of a new 400 kV line (Elbasan-Bitola).'},
#  {'subject': 'Albania',
#   'object': 'Official Journal',
#   'relationship_type': 'in',
#   'description': 'Tariffs for the authorization of new RES plants are published in the Official Journal and in MEI website together with the relevant government decision containing the criteria and procedures for reviewing and granting authorizations.'},
#  {'subject': 'Albania',
#   'object': 'Energy Regulatory Entity',
#   'relationship_type': 'in',
#   'description': 'The authorization procedures of Albania take into account the specificities of different technologies of renewable energies, because they are governed by different legislations.'},
#  {'subject': 'Albania',
#   'object': 'National Territorial Council',
#   'relationship_type': 'in',
#   'description': 'The National Territorial Council is associated with Albania.'},
#  {'subject': 'Albania',
#   'object': 'European',
#   'relationship_type': 'in',
#   'description': 'Albania is located in Europe.'},
#  {'subject': 'Albania',
#   'object': 'European Union',
#   'relationship_type': 'in',
#   'description': 'Albania is a member of the European Union.'},
#  {'subject': 'Albania',
#   'object': 'Ohrid',
#   'relationship_type': 'in',
#   'description': 'Albania has interconnectivity infrastructure with Ohrid'},
#  {'subject': 'Albania',
#   'object': 'Manastir',
#   'relationship_type': 'in',
#   'description': 'Albania has interconnectivity infrastructure with Manastir'},
#  {'subject': 'Albania',
#   'object': 'Elbasan',
#   'relationship_type': 'in',
#   'description': 'Albania has interconnectivity infrastructure with Elbasan'},
#  {'subject': 'Albania',
#   'object': 'North Macedonia',
#   'relationship_type': 'in',
#   'description': 'Albania has interconnectivity infrastructure with North Macedonia'},
#  {'subject': 'Albania',
#   'object': 'Republic of Albania',
#   'relationship_type': 'in',
#   'description': 'N/A'},
#  {'subject': 'Albania',
#   'object': 'Energy Community Secretariat',
#   'relationship_type': 'in',
#   'description': 'The implementation of performance for each area of work indicators is summarised in the figure below and was calculated and compiled by the Energy Community Secretariat.'},
#  {'subject': 'Albania',
#   'object': 'Greece',
#   'relationship_type': 'in',
#   'description': 'Albania has interconnectivity infrastructure with Greece'},
#  {'subject': 'Albania',
#   'object': 'Montenegro',
#   'relationship_type': 'in',
#   'description': 'Albanian operator of the transmission system has already completed a new 400 kV interconnection line with Montenegro (Tirana 2 - Podgorica), which increased the capacity of the Albanian system interconnection up to 1000 MW.'},
#  {'subject': 'Albania',
#   'object': 'Kosovo',
#   'relationship_type': 'in',
#   'description': 'Currently, OST is working to build a new 400 kV line with Kosovo (Tirana 2 - Pristina), which is expected to be completed in 2016.'},
#  {'subject': 'Albania',
#   'object': 'Adriatic',
#   'relationship_type': 'in',
#   'description': 'Albania is located along the Adriatic coastline.'},
#  {'subject': 'Albania',
#   'object': 'European Network of Transmission System Operators for Gas',
#   'relationship_type': 'in',
#   'description': 'N/A'},
#  {'subject': 'Albania',
#   'object': 'Gas Master Plan',
#   'relationship_type': 'in',
#   'description': 'The construction of gas interconnections in Albania is elaborated in details in the Gas Master Plan (GMP) for Albania adopted by the DCM No 87 of 14.02.2018 “On the approval of the Plan for the development of the natural gas sector in Albania and the identification of the priority projects” as well as by the National Territory Council (NTC) with its Decision No 2 of 26 July 2018.'},
#  {'subject': 'Albania',
#   'object': 'Western Balkan',
#   'relationship_type': 'in',
#   'description': 'Albania is located in the Western Balkan region.'},
#  {'subject': 'Albania',
#   'object': 'Trans Adriatic Pipeline',
#   'relationship_type': 'in',
#   'description': 'Albania is one of the transit countries for the Trans Adriatic Pipeline, which will carry Azeri gas across Greece, through Albania, to Italy.'},
#  {'subject': 'Albania',
#   'object': 'South East Europe',
#   'relationship_type': 'in',
#   'description': 'Albania is located in South East Europe.'},
#  {'subject': 'Albania',
#   'object': 'Balkan',
#   'relationship_type': 'in',
#   'description': 'Albania is located in the Balkan region.'},
#  {'subject': 'Albania',
#   'object': 'Central Europe',
#   'relationship_type': 'in',
#   'description': 'Albania is located in Central Europe.'},
#  {'subject': 'Adriatic Integration corridor',
#   'object': 'Albania',
#   'relationship_type': 'focuses_on',
#   'description': 'This market integration option would solve the natural gas supply imbalance in the country, while allowing the country to become a natural trading hub for the region.'},
#  {'subject': 'Gender Inequality Index',
#   'object': 'Albania',
#   'relationship_type': 'focuses_on',
#   'description': 'Albania has a Gender Inequality Index of 0.181.'},
#  {'subject': 'Human Development Index',
#   'object': 'Albania',
#   'relationship_type': 'focuses_on',
#   'description': 'Albania has a Human Development Index of 0.791.'},
#  {'subject': 'Gender Development Index',
#   'object': 'Albania',
#   'relationship_type': 'focuses_on',
#   'description': 'Albania has a Gender Development Index of 0.967.'},
#  {'subject': 'Albania',
#   'object': 'Energy Community',
#   'relationship_type': 'focuses_on',
#   'description': 'Improved alignment and integration of Albanian energy-sector policy and regulation with the Energy Community energy acquis and regional and EU energy markets.'},
#  {'subject': 'Albania',
#   'object': '2030 Agenda',
#   'relationship_type': 'focuses_on',
#   'description': 'UNDP support to development remains highly relevant in Albania.'},
#  {'subject': 'Albania',
#   'object': 'EU Directives',
#   'relationship_type': 'focuses_on',
#   'description': 'Albania has undertaken a series of steps for the inclusion of in its policies for energy, the requests of the EU Directives about the common rules for the creation and the development of internal energy market and the enhancement of production and energy consumption from renewable resources.'},
#  {'subject': 'Albania',
#   'object': 'Vlora',
#   'relationship_type': 'focuses_on',
#   'description': 'The conversion of the Vlora power plant from oil use to gas use once it is connected to the TAP is encouraged. This would contribute to stabilizing the generation of electricity during droughts in the southern part of Albania. However, this will increase gas consumption and thus also CO2 emissions and must be taken into account accordingly in strategic planning.'},
#  {'subject': 'Albania',
#   'object': 'European Union',
#   'relationship_type': 'focuses_on',
#   'description': 'Albania focuses on EU'},
#  {'subject': 'Albania',
#   'object': 'Internal Energy Market',
#   'relationship_type': 'focuses_on',
#   'description': 'Albania has adopted legislation on gas and electricity in line with the EU’s Third energy package.'},
#  {'subject': 'Albania',
#   'object': 'European Green Deal',
#   'relationship_type': 'focuses_on',
#   'description': 'The Energy Strategy for Albania 2018-2030 is fully coherent with the objectives of the European Green Deal.'},
#  {'subject': 'Albania',
#   'object': 'Gross Inland Consumption',
#   'relationship_type': 'focuses_on',
#   'description': 'In terms of Gross inland consumption (to be confirmed) 2019, the Albanian energy system has been dominated and still continues to be dominated by oil by products for transport use (appr. 53.3%), followed by electricity produced from hydropower (appr. 28.17%), and in the third place is biomass (fuelwood, appr. 6.8%) used for heating, cooking and domestic hot water.'},
#  {'subject': 'Albania',
#   'object': 'Energy Community Secretariat',
#   'relationship_type': 'administers',
#   'description': 'The implementation of performance for each area of work indicators is summarised in the figure below and was calculated and compiled by the Energy Community Secretariat.'},
#  {'subject': 'Albania',
#   'object': 'Extractive Industries Transparency Initiative',
#   'relationship_type': 'implements',
#   'description': 'Albania became compliant under the Extractive Industries Transparency Initiative (EITI) in May 2013.'},
#  {'subject': 'Albania',
#   'object': 'National Action Plan for Renewable Energy',
#   'relationship_type': 'implements',
#   'description': 'One of the requests of the law 138/2013 “On Renewable Energy Resources” and of this Directive is the preparation and the approval of the National Action Plan for Renewable Energy (NREAP), which establishes national objectives of renewable energies in the final total domestic consumption as well as the supporting measures to achieve them.'},
#  {'subject': 'Albania',
#   'object': 'Strategic Plan for Reform in Energy Sector in Albania',
#   'relationship_type': 'implements',
#   'description': 'Albania has prepared and adopted a number of policy documents, strategies and action plans aligned with the Energy and Climate Acquis of the Energy Community.'},
#  {'subject': 'Albania',
#   'object': 'European Union',
#   'relationship_type': 'implements',
#   'description': "Albania has adopted legislation on gas and electricity in line with the EU's third energy package."},
#  {'subject': 'Albania',
#   'object': 'Energy Charter Treaty',
#   'relationship_type': 'implements',
#   'description': 'Being a contracting party to the ECT, Albania has made binding commitments to implement the relevant EU Acquis on energy, environment, RES and competition and to promotion of investments, statistics, and social policy.'},
#  {'subject': 'Mati',
#   'object': 'Albania',
#   'relationship_type': 'contributes_to',
#   'description': "Mati contributes to Albania's energy production"},
#  {'subject': 'United Nations Development Programme',
#   'object': 'Albania',
#   'relationship_type': 'contributes_to',
#   'description': 'Risks will be managed through coordination and partnerships; advocacy and policy dialogue; regular monitoring of risks, project and results; and updating of contingency plans for the country office and national emergencies.'},
#  {'subject': 'Kyoto Protocol',
#   'object': 'Albania',
#   'relationship_type': 'contributes_to',
#   'description': 'MoE exercises the powers of the national authority for Clean Development Mechanism projects defined under the Kyoto Protocol in Albania.'},
#  {'subject': 'Ionian Adriatic Pipeline',
#   'object': 'Albania',
#   'relationship_type': 'contributes_to',
#   'description': 'The Gas Master Plan defines the main lines for the development of the gas market and services in Albania based on natural gas supplied through the Trans Adriatic Pipeline (TAP Project), as well as potential gas sources discovered and concretized in the country, or even through natural gas pipelines such as the Ionian Adriatic Pipeline (IAP Project) and the Albania - Kosovo Pipeline (ALKOGAP Project)'},
#  {'subject': 'Vlora TPP',
#   'object': 'Albania',
#   'relationship_type': 'contributes_to',
#   'description': 'The construction of the pipeline that will link the TAP project near the Fier Compressor Station area to the Vlora TPP and the entire Vlora region, will make it possible to restore the Vlora TPP by using natural gas'},
#  {'subject': 'Vlora',
#   'object': 'Albania',
#   'relationship_type': 'contributes_to',
#   'description': 'The construction of the pipeline that will link the TAP project near the Fier Compressor Station area to the Vlora TPP and the entire Vlora region, will make it possible to restore the Vlora TPP by using natural gas'},
#  {'subject': 'Kosovo',
#   'object': 'Albania',
#   'relationship_type': 'contributes_to',
#   'description': 'The integration of the Kosovo and Albania electricity markets improves the investment climate to attract potential generation investors.'},
#  {'subject': 'Devolli',
#   'object': 'Albania',
#   'relationship_type': 'contributes_to',
#   'description': "Devolli contributes to Albania's energy production"},
#  {'subject': 'Vjosa',
#   'object': 'Albania',
#   'relationship_type': 'contributes_to',
#   'description': "Vjosa contributes to Albania's energy production"},
#  {'subject': 'Trans Adriatic Pipeline',
#   'object': 'Albania',
#   'relationship_type': 'contributes_to',
#   'description': 'The Gas Master Plan defines the main lines for the development of the gas market and services in Albania based on natural gas supplied through the Trans Adriatic Pipeline (TAP Project), as well as potential gas sources discovered and concretized in the country, or even through natural gas pipelines such as the Ionian Adriatic Pipeline (IAP Project) and the Albania - Kosovo Pipeline (ALKOGAP Project)'},
#  {'subject': 'Bistrica',
#   'object': 'Albania',
#   'relationship_type': 'contributes_to',
#   'description': "Bistrica contributes to Albania's energy production"},
#  {'subject': 'Drini',
#   'object': 'Albania',
#   'relationship_type': 'contributes_to',
#   'description': "Drini contributes to Albania's energy production"},
#  {'subject': 'Finiq-Karne',
#   'object': 'Albania',
#   'relationship_type': 'contributes_to',
#   'description': 'Finiq-Karne contributes to the development of the oil and gas sector in Albania.'},
#  {'subject': 'Albanian',
#   'object': 'Albania',
#   'relationship_type': 'contributes_to',
#   'description': 'Albania contributes to the development of the Albanian power sector.'},
#  {'subject': 'Albania',
#   'object': 'Paris Accords',
#   'relationship_type': 'contributes_to',
#   'description': 'Albania contributes to the Paris Accords'},
#  {'subject': 'Albania',
#   'object': 'United Nations Development Programme',
#   'relationship_type': 'contributes_to',
#   'description': 'Albania will contribute to the priorities of UNDP.'},
#  {'subject': 'Albania',
#   'object': 'EU Directive',
#   'relationship_type': 'contributes_to',
#   'description': 'Albania is compelled to transpose and be in compliance with the EU Directive 2009/28/EC'},
#  {'subject': 'Albania',
#   'object': 'Directive',
#   'relationship_type': 'contributes_to',
#   'description': 'Albania is compelled to transpose and be in compliance with the EU Directive 2009/28/EC'},
#  {'subject': 'Albania',
#   'object': 'Third Energy Package',
#   'relationship_type': 'contributes_to',
#   'description': "Albania's energy sector transformation aligns with the objectives of the Third Energy Package"},
#  {'subject': 'Albania',
#   'object': 'Internal Energy Market',
#   'relationship_type': 'contributes_to',
#   'description': 'Albania has made progress in the legal unbundling of the distribution-system operator OSHEE SA from its supply activity.'},
#  {'subject': 'Albania',
#   'object': 'Kosovo',
#   'relationship_type': 'contributes_to',
#   'description': 'The integration of the Albania and Kosovo electricity markets improves the investment climate to attract potential generation investors.'},
#  {'subject': 'Albania',
#   'object': 'European Union',
#   'relationship_type': 'aligns_with',
#   'description': 'Given the current status of Albania as a candidate country in accession to the EU, it is likely during the period covered by this strategy Albania will accede to the EU.'},
#  {'subject': 'Albania',
#   'object': 'European',
#   'relationship_type': 'aligns_with',
#   'description': 'Albania is partially aligned with the Acquis on a single European railway area, railway system interoperability and rail freight corridors for competitive freight.'},
#  {'subject': 'Albania',
#   'object': 'Paris Agreement',
#   'relationship_type': 'aligns_with',
#   'description': 'The Paris Agreement, adopted in December 2015, provides a common framework for all Parties aimed at holding the increase in the global average temperature to well below 2° C above pre-industrial levels.'},
#  {'subject': 'Energy Sector Strategy',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'The Energy Sector Strategy represents a synthesis of detailed energy sector analysis, and other sectoral and cross-sectoral strategic and planning documents, much of which was incorporated into an analytical review of future development pathways for Albania’s energy sector.'},
#  {'subject': 'Kyoto Protocol',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'The law transposes the previous EU Directive2003/30/EC of 8 May 2003 on the promotion of bio-fuels or other renewable fuels used for transport.'},
#  {'subject': 'Vlora',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'The conversion of the Vlora power plant from oil use to gas use once it is connected to the TAP is encouraged. This would contribute to stabilizing the generation of electricity during droughts in the southern part of Albania. However, this will increase gas consumption and thus also CO2 emissions and must be taken into account accordingly in strategic planning.'},
#  {'subject': 'Natural Gas Market Model',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'In October 2018, Albania adopted the Natural Gas Market Model.'},
#  {'subject': 'Albanian Parliament',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'The Energy Strategy addresses new laws, regulations and institutional reforms currently underway in Albania, including incentives for EE and RES, electricity tariff reform, market development and integration with EU and regional markets.'},
#  {'subject': 'Ukraine South Integration corridor',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'Albania can take advantage of its geographical location within the Western Balkan region and become part of a more robust gas market.'},
#  {'subject': 'Adriatic Integration Corridor',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'Albania can take advantage of its geographical location within the Western Balkan region and become a key player in the development and deployment of a regional gas transmission network for a sub-regional market.'},
#  {'subject': 'Energy Efficiency Law',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'The development of secondary legislation for implementing the Power Sector, Oil & Natural Gas, RES and EPB Laws in Albania.'},
#  {'subject': 'Electricity Market Model',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'The discussions included the Electricity Market Model in Albania.'},
#  {'subject': 'Agency for Energy Efficiency',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'The discussions included the creation of an Agency for Energy Efficiency in Albania.'},
#  {'subject': 'Kosovo',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'The Albania-Kosovo Coupling scenario assesses the impacts of integrating the operation of the electricity markets in Albania and Kosovo as a first step towards a regional coupled electricity market.'},
#  {'subject': 'Energy Strategy',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'Implementing this Energy Strategy will increase the security of Albania’s energy supply and begin to integrate the Albanian energy market into regional and European markets.'},
#  {'subject': 'Law on the Power Sector',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': "The Law on the Power Sector is directed towards tackling issues in Albania's power sector."},
#  {'subject': 'EE Scenario',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'This chapter proposes recommendations for financing mechanisms and fiscal incentives in Albania to support the sustainable implementation of the Second NEEAP as well as to implement all measures presented under the EE Scenario presented in Section 1 of this strategy.'},
#  {'subject': 'Government',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'In principle, this problem can be addressed by significant financial injections from the Government, by policy and other reforms to improve the financial performance of sector entities or by a combination of these two approaches.'},
#  {'subject': 'Albania',
#   'object': 'Energy Community',
#   'relationship_type': 'addresses',
#   'description': 'Potential to reduce energy imports by 32% compared to the Baseline scenario;'},
#  {'subject': 'Albania',
#   'object': 'EU Directive',
#   'relationship_type': 'addresses',
#   'description': 'Albania is compelled to transpose and be in compliance with the EU Directive 2009/28/EC'},
#  {'subject': 'Albania',
#   'object': 'Directive',
#   'relationship_type': 'addresses',
#   'description': 'Albania is compelled to transpose and be in compliance with the EU Directive 2009/28/EC'},
#  {'subject': 'Albania',
#   'object': 'National Action Plan for Renewable Energy',
#   'relationship_type': 'addresses',
#   'description': 'One of the requests of the law 138/2013 “On Renewable Energy Resources” and of this Directive is the preparation and the approval of the National Action Plan for Renewable Energy (NREAP), which establishes national objectives of renewable energies in the final total domestic consumption as well as the supporting measures to achieve them.'},
#  {'subject': 'Albania',
#   'object': 'Second National Strategy for Development and Integration',
#   'relationship_type': 'addresses',
#   'description': 'The principles guiding the development of the Albanian Energy Sector Strategy are fully in line with the principles of the Second National Strategy for Development and Integration.'},
#  {'subject': 'Albania',
#   'object': 'Albanian Energy Sector Strategy',
#   'relationship_type': 'addresses',
#   'description': 'Integration into the regional and EU energy markets is one of the main objectives of the Albanian Energy Sector Strategy which underline that energy security has to be achieved based on energy sources diversification, solidarity and trust.'},
#  {'subject': 'Albania',
#   'object': 'Gross Inland Consumption',
#   'relationship_type': 'addresses',
#   'description': 'In terms of Gross inland consumption (to be confirmed) 2019, the Albanian energy system has been dominated and still continues to be dominated by oil by products for transport use (appr. 53.3%), followed by electricity produced from hydropower (appr. 28.17%), and in the third place is biomass (fuelwood, appr. 6.8%) used for heating, cooking and domestic hot water.'},
#  {'subject': 'Albania',
#   'object': 'Third Energy Package',
#   'relationship_type': 'addresses',
#   'description': "Albania's National Strategy of Energy 2018–2030 aims to align with the Third Energy Package"},
#  {'subject': 'Albania',
#   'object': 'Energy Community Secretariat',
#   'relationship_type': 'addresses',
#   'description': 'The figure below shows the implementation by oil indicators as calculated and compiled by the Energy Community Secretariat.'},
#  {'subject': 'Albania',
#   'object': 'Eco-design Directive',
#   'relationship_type': 'addresses',
#   'description': 'Law on “Energy consumption Information and on other products related to the energy" No. 68/2012 Needs to be recast according to the new EU Eco-design and Labelling Policy (Eco-design Directive 2009/125/EC and Energy Labelling framework Regulation EU 2017/1369)'},
#  {'subject': 'Albania',
#   'object': 'Strategic Plan for Reform in Energy Sector in Albania',
#   'relationship_type': 'addresses',
#   'description': 'Albania has prepared and adopted a number of policy documents, strategies and action plans aligned with the Energy and Climate Acquis of the Energy Community.'},
#  {'subject': 'Albania',
#   'object': 'Strategy',
#   'relationship_type': 'addresses',
#   'description': 'towards a diversified energy system using alternative energy resources like gas and renewables with less GHG emissions, and implementation of energy efficiency measures - based on cost effectiveness.'},
#  {'subject': 'Albania',
#   'object': 'European Union',
#   'relationship_type': 'addresses',
#   'description': 'Albania has adopted legislation on gas and electricity in line with the EU’s Third energy package.'},
#  {'subject': 'Albania',
#   'object': 'Albanian',
#   'relationship_type': 'addresses',
#   'description': 'Potential to increase the RES share past 2020 by focusing the gas infrastructure investment to provide gas access to the power and industry sectors and not residential and commercial customers;'},
#  {'subject': 'Albania',
#   'object': 'Kosovo',
#   'relationship_type': 'addresses',
#   'description': 'The Albania-Kosovo Coupling scenario assesses the impacts of integrating the operation of the electricity markets in Albania and Kosovo as a first step towards a regional coupled electricity market.'},
#  {'subject': 'Bankers Petroleum (a Canadian oil company)',
#   'object': 'Albania',
#   'relationship_type': 'funds',
#   'description': "Bankers Petroleum provides financial support to projects in Albania's oil and gas sector."},
#  {'subject': 'Agence Française de Développement',
#   'object': 'Albania',
#   'relationship_type': 'funds',
#   'description': 'Upcoming PEEB Cool: Albania to be included in PEEB Cool, with funding dedicated (loans + grants) to EE improvement of public buildings'},
#  {'subject': 'Albania',
#   'object': 'Memorandum of Understanding',
#   'relationship_type': 'funds',
#   'description': 'Albania provides financial support for the implementation of the Memorandum of Understanding.'},
#  {'subject': 'National Sector Strategy for Energy',
#   'object': 'Albania',
#   'relationship_type': 'targets',
#   'description': 'The National Sector Strategy for Energy targets Albania.'},
#  {'subject': 'National Energy Strategy',
#   'object': 'Albania',
#   'relationship_type': 'targets',
#   'description': 'The Renewable Energy scenario presented in the National Energy Strategy incorporates Albania’s National Renewable Energy Action Plan (NREAP) 2019.'},
#  {'subject': 'National Sector Strategy for Transport',
#   'object': 'Albania',
#   'relationship_type': 'targets',
#   'description': 'The aim has been to significantly contribute to overall economic growth and development of the economy.'},
#  {'subject': 'Albania',
#   'object': 'Paris Agreement',
#   'relationship_type': 'targets',
#   'description': 'Albania aims to achieve the goals set in the Paris Agreement.'},
#  {'subject': 'Albania',
#   'object': 'Vlora',
#   'relationship_type': 'targets',
#   'description': 'The Vlora thermal power plant (built with financing from the EBRD of EUR 40 million, EIB financing of EUR 40 million, and WB* financing of EUR 20.5 million) has never been put into operation since its completion in 2011. This is due to a failure in the plant’s cooling system that has not been repaired.'},
#  {'subject': 'Albania',
#   'object': 'Gross Inland Consumption',
#   'relationship_type': 'targets',
#   'description': 'In terms of Gross inland consumption (to be confirmed) 2019, the Albanian energy system has been dominated and still continues to be dominated by oil by products for transport use (appr. 53.3%), followed by electricity produced from hydropower (appr. 28.17%), and in the third place is biomass (fuelwood, appr. 6.8%) used for heating, cooking and domestic hot water.'},
#  {'subject': 'Albania',
#   'object': 'Directive 2012/27/EU',
#   'relationship_type': 'targets',
#   'description': 'Based on Article 4 of Directive 2012/27/EU on energy efficiency in building renovation, Albania has not yet completed the strategy for supporting and encouraging cost effective investments in the renovation of the national building stock.'},
#  {'subject': 'Albania',
#   'object': 'National Energy Efficiency Action Plan',
#   'relationship_type': 'targets',
#   'description': 'The National Energy Efficiency Action Plan 2017 – 2020 will be updated for the period 2021-2030 as an integral part of the National Energy and Climate Plan (NECP) 2021 – 2030.'},
#  {'subject': 'Albania',
#   'object': 'Strategy',
#   'relationship_type': 'targets',
#   'description': 'The system must rely on domestic production and being affordable for consumers by creating an impact on poverty reduction.'},
#  {'subject': 'Master Plan of Natural Gas for Albania',
#   'object': 'Albania',
#   'relationship_type': 'an_instance_of',
#   'description': 'The Master Plan of Natural Gas for Albania is an instance of Albania.'},
#  {'subject': 'Energy Regulatory Entity',
#   'object': 'Republic of Albania',
#   'relationship_type': 'in',
#   'description': 'N/A'},
#  {'subject': 'Republic of Albania',
#   'object': 'Energy Regulatory Entity',
#   'relationship_type': 'in',
# ...
#  {'subject': 'Energy Sector Strategy',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'The Energy Sector Strategy represents a synthesis of detailed energy sector analysis, and other sectoral and cross-sectoral strategic and planning documents, much of which was incorporated into an analytical review of future development pathways for Albania’s energy sector.'},
#  {'subject': 'Kyoto Protocol',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'The law transposes the previous EU Directive2003/30/EC of 8 May 2003 on the promotion of bio-fuels or other renewable fuels used for transport.'},
#  {'subject': 'Vlora',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'The conversion of the Vlora power plant from oil use to gas use once it is connected to the TAP is encouraged. This would contribute to stabilizing the generation of electricity during droughts in the southern part of Albania. However, this will increase gas consumption and thus also CO2 emissions and must be taken into account accordingly in strategic planning.'},
#  {'subject': 'Natural Gas Market Model',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'In October 2018, Albania adopted the Natural Gas Market Model.'},
#  {'subject': 'Albanian Parliament',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'The Energy Strategy addresses new laws, regulations and institutional reforms currently underway in Albania, including incentives for EE and RES, electricity tariff reform, market development and integration with EU and regional markets.'},
#  {'subject': 'Ukraine South Integration corridor',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'Albania can take advantage of its geographical location within the Western Balkan region and become part of a more robust gas market.'},
#  {'subject': 'Adriatic Integration Corridor',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'Albania can take advantage of its geographical location within the Western Balkan region and become a key player in the development and deployment of a regional gas transmission network for a sub-regional market.'},
#  {'subject': 'Energy Efficiency Law',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'The development of secondary legislation for implementing the Power Sector, Oil & Natural Gas, RES and EPB Laws in Albania.'},
#  {'subject': 'Electricity Market Model',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'The discussions included the Electricity Market Model in Albania.'},
#  {'subject': 'Agency for Energy Efficiency',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'The discussions included the creation of an Agency for Energy Efficiency in Albania.'},
#  {'subject': 'Kosovo',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'The Albania-Kosovo Coupling scenario assesses the impacts of integrating the operation of the electricity markets in Albania and Kosovo as a first step towards a regional coupled electricity market.'},
#  {'subject': 'Energy Strategy',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'Implementing this Energy Strategy will increase the security of Albania’s energy supply and begin to integrate the Albanian energy market into regional and European markets.'},
#  {'subject': 'Law on the Power Sector',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': "The Law on the Power Sector is directed towards tackling issues in Albania's power sector."},
#  {'subject': 'EE Scenario',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'This chapter proposes recommendations for financing mechanisms and fiscal incentives in Albania to support the sustainable implementation of the Second NEEAP as well as to implement all measures presented under the EE Scenario presented in Section 1 of this strategy.'},
#  {'subject': 'Government',
#   'object': 'Albania',
#   'relationship_type': 'addresses',
#   'description': 'In principle, this problem can be addressed by significant financial injections from the Government, by policy and other reforms to improve the financial performance of sector entities or by a combination of these two approaches.'},
#  {'subject': 'Albania',
#   'object': 'Energy Community',
#   'relationship_type': 'addresses',
#   'description': 'Potential to reduce energy imports by 32% compared to the Baseline scenario;'},
#  {'subject': 'Albania',
#   'object': 'EU Directive',
#   'relationship_type': 'addresses',
#   'description': 'Albania is compelled to transpose and be in compliance with the EU Directive 2009/28/EC'},
#  {'subject': 'Albania',
#   'object': 'Directive',
#   'relationship_type': 'addresses',
#   'description': 'Albania is compelled to transpose and be in compliance with the EU Directive 2009/28/EC'},
#  {'subject': 'Albania',
#   'object': 'National Action Plan for Renewable Energy',
#   'relationship_type': 'addresses',
#   'description': 'One of the requests of the law 138/2013 “On Renewable Energy Resources” and of this Directive is the preparation and the approval of the National Action Plan for Renewable Energy (NREAP), which establishes national objectives of renewable energies in the final total domestic consumption as well as the supporting measures to achieve them.'},
#  {'subject': 'Albania',
#   'object': 'Second National Strategy for Development and Integration',
#   'relationship_type': 'addresses',
#   'description': 'The principles guiding the development of the Albanian Energy Sector Strategy are fully in line with the principles of the Second National Strategy for Development and Integration.'},
#  {'subject': 'Albania',
#   'object': 'Albanian Energy Sector Strategy',
#   'relationship_type': 'addresses',
#   'description': 'Integration into the regional and EU energy markets is one of the main objectives of the Albanian Energy Sector Strategy which underline that energy security has to be achieved based on energy sources diversification, solidarity and trust.'},
#  {'subject': 'Albania',
#   'object': 'Gross Inland Consumption',
#   'relationship_type': 'addresses',
#   'description': 'In terms of Gross inland consumption (to be confirmed) 2019, the Albanian energy system has been dominated and still continues to be dominated by oil by products for transport use (appr. 53.3%), followed by electricity produced from hydropower (appr. 28.17%), and in the third place is biomass (fuelwood, appr. 6.8%) used for heating, cooking and domestic hot water.'},
#  {'subject': 'Albania',
#   'object': 'Third Energy Package',
#   'relationship_type': 'addresses',
#   'description': "Albania's National Strategy of Energy 2018–2030 aims to align with the Third Energy Package"},
#  {'subject': 'Albania',
#   'object': 'Energy Community Secretariat',
#   'relationship_type': 'addresses',
#   'description': 'The figure below shows the implementation by oil indicators as calculated and compiled by the Energy Community Secretariat.'},
#  {'subject': 'Albania',
#   'object': 'Eco-design Directive',
#   'relationship_type': 'addresses',
#   'description': 'Law on “Energy consumption Information and on other products related to the energy" No. 68/2012 Needs to be recast according to the new EU Eco-design and Labelling Policy (Eco-design Directive 2009/125/EC and Energy Labelling framework Regulation EU 2017/1369)'},
#  {'subject': 'Albania',
#   'object': 'Strategic Plan for Reform in Energy Sector in Albania',
#   'relationship_type': 'addresses',
#   'description': 'Albania has prepared and adopted a number of policy documents, strategies and action plans aligned with the Energy and Climate Acquis of the Energy Community.'},
#  {'subject': 'Albania',
#   'object': 'Strategy',
#   'relationship_type': 'addresses',
#   'description': 'towards a diversified energy system using alternative energy resources like gas and renewables with less GHG emissions, and implementation of energy efficiency measures - based on cost effectiveness.'},
#  {'subject': 'Albania',
#   'object': 'European Union',
#   'relationship_type': 'addresses',
#   'description': 'Albania has adopted legislation on gas and electricity in line with the EU’s Third energy package.'},
#  {'subject': 'Albania',
#   'object': 'Albanian',
#   'relationship_type': 'addresses',
#   'description': 'Potential to increase the RES share past 2020 by focusing the gas infrastructure investment to provide gas access to the power and industry sectors and not residential and commercial customers;'},
#  {'subject': 'Albania',
#   'object': 'Kosovo',
#   'relationship_type': 'addresses',
#   'description': 'The Albania-Kosovo Coupling scenario assesses the impacts of integrating the operation of the electricity markets in Albania and Kosovo as a first step towards a regional coupled electricity market.'},
#  {'subject': 'Bankers Petroleum (a Canadian oil company)',
#   'object': 'Albania',
#   'relationship_type': 'funds',
#   'description': "Bankers Petroleum provides financial support to projects in Albania's oil and gas sector."},
#  {'subject': 'Agence Française de Développement',
#   'object': 'Albania',
#   'relationship_type': 'funds',
#   'description': 'Upcoming PEEB Cool: Albania to be included in PEEB Cool, with funding dedicated (loans + grants) to EE improvement of public buildings'},
#  {'subject': 'Albania',
#   'object': 'Memorandum of Understanding',
#   'relationship_type': 'funds',
#   'description': 'Albania provides financial support for the implementation of the Memorandum of Understanding.'},
#  {'subject': 'National Sector Strategy for Energy',
#   'object': 'Albania',
#   'relationship_type': 'targets',
#   'description': 'The National Sector Strategy for Energy targets Albania.'},
#  {'subject': 'National Energy Strategy',
#   'object': 'Albania',
#   'relationship_type': 'targets',
#   'description': 'The Renewable Energy scenario presented in the National Energy Strategy incorporates Albania’s National Renewable Energy Action Plan (NREAP) 2019.'},
#  {'subject': 'National Sector Strategy for Transport',
#   'object': 'Albania',
#   'relationship_type': 'targets',
#   'description': 'The aim has been to significantly contribute to overall economic growth and development of the economy.'},
#  {'subject': 'Albania',
#   'object': 'Paris Agreement',
#   'relationship_type': 'targets',
#   'description': 'Albania aims to achieve the goals set in the Paris Agreement.'},
#  {'subject': 'Albania',
#   'object': 'Vlora',
#   'relationship_type': 'targets',
#   'description': 'The Vlora thermal power plant (built with financing from the EBRD of EUR 40 million, EIB financing of EUR 40 million, and WB* financing of EUR 20.5 million) has never been put into operation since its completion in 2011. This is due to a failure in the plant’s cooling system that has not been repaired.'},
#  {'subject': 'Albania',
#   'object': 'Gross Inland Consumption',
#   'relationship_type': 'targets',
#   'description': 'In terms of Gross inland consumption (to be confirmed) 2019, the Albanian energy system has been dominated and still continues to be dominated by oil by products for transport use (appr. 53.3%), followed by electricity produced from hydropower (appr. 28.17%), and in the third place is biomass (fuelwood, appr. 6.8%) used for heating, cooking and domestic hot water.'},
#  {'subject': 'Albania',
#   'object': 'Directive 2012/27/EU',
#   'relationship_type': 'targets',
#   'description': 'Based on Article 4 of Directive 2012/27/EU on energy efficiency in building renovation, Albania has not yet completed the strategy for supporting and encouraging cost effective investments in the renovation of the national building stock.'},
#  {'subject': 'Albania',
#   'object': 'National Energy Efficiency Action Plan',
#   'relationship_type': 'targets',
#   'description': 'The National Energy Efficiency Action Plan 2017 – 2020 will be updated for the period 2021-2030 as an integral part of the National Energy and Climate Plan (NECP) 2021 – 2030.'},
#  {'subject': 'Albania',
#   'object': 'Strategy',
#   'relationship_type': 'targets',
#   'description': 'The system must rely on domestic production and being affordable for consumers by creating an impact on poverty reduction.'},
#  {'subject': 'Master Plan of Natural Gas for Albania',
#   'object': 'Albania',
#   'relationship_type': 'an_instance_of',
#   'description': 'The Master Plan of Natural Gas for Albania is an instance of Albania.'},
#  {'subject': 'Energy Regulatory Entity',
#   'object': 'Republic of Albania',
#   'relationship_type': 'in',
#   'description': 'N/A'},
#  {'subject': 'Republic of Albania',
#   'object': 'Energy Regulatory Entity',
#   'relationship_type': 'in',
#   'description': 'Authorizations for the construction of installations of renewable energy are granted by the Council of Ministers or by the requirements of the law on concessions for hydropower plants, or as required by law for the energy sector to other types of producers of electricity using renewable energy, or the law on bio-fuels for bio-fuel producers.'},
#  {'subject': 'Ministry of Energy and Industry',
#   'object': 'Republic of Albania',
#   'relationship_type': 'addresses',
#   'description': 'The Ministry of Energy and Industry addresses the issues and goals of the Republic of Albania.'},
#  {'subject': 'Albania',
#   'object': 'Republic of Albania',
#   'relationship_type': 'in',
#   'description': 'N/A'},
#  {'subject': 'Republic of Albania',
#   'object': 'Republic of Albania',
#   'relationship_type': 'in',
#   'description': 'Each company holding a license for "Wholesale trade of oil, gas, by-products, including bio, as well as fuels, with code VIII.1.A" for wholesale trade in the market must take measures to ensure the placement on the market of the minimum quantity of biofuels and other renewable fuels.'},
#  {'subject': 'Republic of Albania',
#   'object': 'Draft Law',
#   'relationship_type': 'in',
#   'description': 'The Draft Law is associated with the Republic of Albania.'},
#  {'subject': 'Gross Final Energy Consumption',
#   'object': 'Republic of Albania',
#   'relationship_type': 'contributes_to',
#   'description': 'Increase of energy production from renewable sources to ensure a sustainable development in the Republic of Albania, in accordance with the obligations under the Energy Community Treaty'},
#  {'subject': 'Gross Final Energy',
#   'object': 'Republic of Albania',
#   'relationship_type': 'contributes_to',
#   'description': 'Gross Final Energy contributes to the Republic of Albania.'},
#  {'subject': 'Republic of Albania',
#   'object': 'Albgaz Sh.a',
#   'relationship_type': 'administers',
#   'description': 'The Republic of Albania administers Albgaz Sh.a.'},
#  {'subject': 'Republic of Albania',
#   'object': 'Secretariat of the Energy Community',
#   'relationship_type': 'partners_with',
#   'description': 'As announced at the Energy Community Ministerial Council meeting on 14 December 2017, the Republic of Albania will engage, in cooperation with the Secretariat of the Energy Community, in elaborating and adopting an Integrated Energy and Climate Plan in the course of 2018.'},
#  {'subject': 'Secretariat of the Energy Community',
#   'object': 'Republic of Albania',
#   'relationship_type': 'partners_with',
#   'description': 'As announced at the Energy Community Ministerial Council meeting on 14 December 2017, the Republic of Albania will engage, in cooperation with the Secretariat of the Energy Community, in elaborating and adopting an Integrated Energy and Climate Plan in the course of 2018.'},
#  {'subject': 'Energy Sector Strategy',
#   'object': 'Republic of Albania',
#   'relationship_type': 'addresses',
#   'description': 'The Energy Sector Strategy represents a synthesis of detailed energy sector analysis, and other sectoral and cross-sectoral strategic and planning documents, much of which was incorporated into an analytical review of future development pathways for Albania’s energy sector.'}]

# %%
entities
# Out:
# [{'name': 'Gender Development Index',
#   'category': 'Strategy',
#   'acronym': 'GDI'},
#  {'name': 'Albania', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'United Nations Development Programme',
#   'category': 'Organization',
#   'acronym': 'UNDP'},
#  {'name': 'United Nations agencies',
#   'category': 'Organization',
#   'acronym': 'N/A'},
#  {'name': 'United Nations', 'category': 'Organization', 'acronym': 'UN'},
#  {'name': 'United Nations Population Fund',
#   'category': 'Organization',
#   'acronym': 'UNFPA'},
#  {'name': 'Government', 'category': 'Organization', 'acronym': 'Government'},
#  {'name': 'Sustainable Development Goals',
#   'category': 'Strategy',
#   'acronym': 'SDGs'},
#  {'name': 'United Nations Office for Project Services',
#   'category': 'Organization',
#   'acronym': 'UNOPS'},
#  {'name': 'United Nations Sustainable Development Cooperation Framework',
#   'category': 'Organization',
#   'acronym': 'UNSDCF'},
#  {'name': 'National Statistical Office',
#   'category': 'Organization',
#   'acronym': 'N/A'},
#  {'name': 'European Union', 'category': 'Organization', 'acronym': 'EU'},
#  {'name': 'Executive Board', 'category': 'Organization', 'acronym': 'N/A'},
#  {'name': 'People’s Advocate', 'category': 'Organization', 'acronym': 'N/A'},
#  {'name': 'National Public Administration Reform Strategy',
#   'category': 'Project',
#   'acronym': 'N/A'},
#  {'name': 'Albanian Government', 'category': 'Organization', 'acronym': 'N/A'},
#  {'name': 'Strategy', 'category': 'Strategy', 'acronym': 'N/A'},
#  {'name': 'Gross Inland Consumption', 'category': 'Event', 'acronym': 'GIC'},
#  {'name': 'Ministry of Infrastructure and Energy',
#   'category': 'Organization',
#   'acronym': 'MIE'},
#  {'name': 'Kosovo', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'World Trade Organization',
#   'category': 'Organization',
#   'acronym': 'N/A'},
#  {'name': 'Austria', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Germany', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Council of Ministers', 'category': 'Organization', 'acronym': 'CM'},
#  {'name': 'Serbia', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Montenegro', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Bosnia and Herzegovina', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'National Territory Council',
#   'category': 'Organization',
#   'acronym': 'NTC'},
#  {'name': 'Greece', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Croatia', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Ionian Adriatic Pipeline', 'category': 'Project', 'acronym': 'IAP'},
#  {'name': 'Ukraine South Integration corridor',
#   'category': 'Project',
#   'acronym': 'N/A'},
#  {'name': 'Adriatic Integration Corridor',
#   'category': 'Project',
#   'acronym': 'N/A'},
#  {'name': 'European Bank for Reconstruction and Development',
#   'category': 'Organization',
#   'acronym': 'EBRD'},
#  {'name': 'Municipality of Tirana',
#   'category': 'Organization',
#   'acronym': 'N/A'},
#  {'name': 'European Network of Transmission System Operators for Gas',
#   'category': 'Organization',
#   'acronym': 'ENTSO-G'},
#  {'name': 'Romania', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Bulgaria', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Moldova', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Ukraine', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Macedonia', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'United Nations Framework Convention on Climate Change',
#   'category': 'Organization',
#   'acronym': 'UNFCCC'},
#  {'name': 'International Finance Corporation',
#   'category': 'Organization',
#   'acronym': 'IFC'},
#  {'name': 'United States Agency for International Development',
#   'category': 'Organization',
#   'acronym': 'USAID'},
#  {'name': 'Ministry of Energy and Industry',
#   'category': 'Organization',
#   'acronym': 'MEI'},
#  {'name': 'Albanian Electricity Distribution System Operator',
#   'category': 'Organization',
#   'acronym': 'OShEE'},
#  {'name': 'Italy', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Trans Adriatic Pipeline AG',
#   'category': 'Organization',
#   'acronym': 'TAP AG'},
#  {'name': 'Ballsh', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Bistrica', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Devoll', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Vjosa', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Mat', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Devoll River', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'North Macedonia', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Fier', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Dumre', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Fier Compressor Station', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Tirana', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Durres', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Porto Romano', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Elbasan', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Tirana2', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Kosova B', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'New York', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Macedonian', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Official Journal', 'category': 'Organization', 'acronym': 'N/A'},
#  {'name': 'Energy Regulatory Entity',
#   'category': 'Organization',
#   'acronym': 'ERE'},
#  {'name': 'National Territorial Council',
#   'category': 'Organization',
#   'acronym': 'N/A'},
#  {'name': 'European', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Ohrid', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Manastir', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Republic of Albania', 'category': 'Location', 'acronym': 'Albania'},
#  {'name': 'Energy Community Secretariat',
#   'category': 'Organization',
#   'acronym': 'ERBD'},
#  {'name': 'Adriatic', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Gas Master Plan', 'category': 'Strategy', 'acronym': 'GMP'},
#  {'name': 'Western Balkan', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Trans Adriatic Pipeline', 'category': 'Project', 'acronym': 'TAP'},
#  {'name': 'South East Europe', 'category': 'Location', 'acronym': 'SEE'},
#  {'name': 'Balkan', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Central Europe', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Adriatic Integration corridor',
#   'category': 'Project',
#   'acronym': 'N/A'},
#  {'name': 'Gender Inequality Index', 'category': 'Strategy', 'acronym': 'GII'},
#  {'name': 'Human Development Index', 'category': 'Strategy', 'acronym': 'N/A'},
#  {'name': 'Energy Community', 'category': 'Organization', 'acronym': 'EC'},
#  {'name': '2030 Agenda', 'category': 'Strategy', 'acronym': 'N/A'},
#  {'name': 'EU Directives', 'category': 'Strategy', 'acronym': 'N/A'},
#  {'name': 'Vlora', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Internal Energy Market', 'category': 'Strategy', 'acronym': 'N/A'},
#  {'name': 'European Green Deal', 'category': 'Strategy', 'acronym': 'N/A'},
#  {'name': 'Extractive Industries Transparency Initiative',
#   'category': 'Organization',
#   'acronym': 'EITI'},
#  {'name': 'National Action Plan for Renewable Energy',
#   'category': 'Project',
#   'acronym': 'N/A'},
#  {'name': 'Strategic Plan for Reform in Energy Sector in Albania',
#   'category': 'Strategy',
#   'acronym': 'N/A'},
#  {'name': 'Energy Charter Treaty',
#   'category': 'Organization',
#   'acronym': 'ECT'},
#  {'name': 'Mati', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Kyoto Protocol', 'category': 'Project', 'acronym': 'N/A'},
#  {'name': 'Vlora TPP', 'category': 'Organization', 'acronym': 'N/A'},
#  {'name': 'Devolli', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Drini', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Finiq-Karne', 'category': 'Organization', 'acronym': 'N/A'},
#  {'name': 'Albanian', 'category': 'Location', 'acronym': 'N/A'},
#  {'name': 'Paris Accords', 'category': 'Event', 'acronym': 'N/A'},
#  {'name': 'EU Directive', 'category': 'Strategy', 'acronym': 'N/A'},
#  {'name': 'Directive', 'category': 'Organization', 'acronym': 'N/A'},
#  {'name': 'Third Energy Package', 'category': 'Strategy', 'acronym': 'N/A'},
#  {'name': 'Paris Agreement', 'category': 'Event', 'acronym': 'N/A'},
#  {'name': 'Energy Sector Strategy', 'category': 'Strategy', 'acronym': 'N/A'},
#  {'name': 'Natural Gas Market Model',
#   'category': 'Strategy',
#   'acronym': 'N/A'},
#  {'name': 'Albanian Parliament', 'category': 'Organization', 'acronym': 'N/A'},
#  {'name': 'Energy Efficiency Law',
#   'category': 'Strategy',
#   'acronym': 'EE Law'},
#  {'name': 'Electricity Market Model',
#   'category': 'Strategy',
#   'acronym': 'N/A'},
#  {'name': 'Agency for Energy Efficiency',
#   'category': 'Organization',
#   'acronym': 'AEE'},
#  {'name': 'Energy Strategy', 'category': 'Strategy', 'acronym': 'N/A'},
#  {'name': 'Law on the Power Sector',
#   'category': 'Organization',
#   'acronym': 'N/A'},
#  {'name': 'EE Scenario', 'category': 'Strategy', 'acronym': 'N/A'},
#  {'name': 'Second National Strategy for Development and Integration',
#   'category': 'Strategy',
#   'acronym': 'N/A'},
#  {'name': 'Albanian Energy Sector Strategy',
#   'category': 'Strategy',
#   'acronym': 'N/A'},
#  {'name': 'Eco-design Directive', 'category': 'Strategy', 'acronym': 'N/A'},
#  {'name': 'Bankers Petroleum (a Canadian oil company)',
#   'category': 'Organization',
#   'acronym': 'Bankers Petroleum'},
#  {'name': 'Agence Française de Développement',
#   'category': 'Organization',
#   'acronym': 'AFD'},
#  {'name': 'Memorandum of Understanding',
#   'category': 'Event',
#   'acronym': 'N/A'},
#  {'name': 'National Sector Strategy for Energy',
#   'category': 'Strategy',
#   'acronym': 'N/A'},
#  {'name': 'National Energy Strategy',
#   'category': 'Strategy',
#   'acronym': 'NSE'},
#  {'name': 'National Sector Strategy for Transport',
#   'category': 'Strategy',
#   'acronym': 'N/A'},
#  {'name': 'Directive 2012/27/EU', 'category': 'Strategy', 'acronym': 'N/A'},
#  {'name': 'National Energy Efficiency Action Plan',
#   'category': 'Project',
#   'acronym': 'NEEAP'},
#  {'name': 'Master Plan of Natural Gas for Albania',
#   'category': 'Project',
#   'acronym': 'N/A'},
#  {'name': 'Draft Law', 'category': 'Event', 'acronym': 'N/A'},
#  {'name': 'Gross Final Energy Consumption',
#   'category': 'Event',
#   'acronym': 'N/A'},
#  {'name': 'Gross Final Energy', 'category': 'Product', 'acronym': 'N/A'},
#  {'name': 'Albgaz Sh.a', 'category': 'Organization', 'acronym': 'Albgaz'},
#  {'name': 'Secretariat of the Energy Community',
#   'category': 'Organization',
#   'acronym': 'N/A'}]

# %%
indicators_dict=indicatorsModule(test_query)
print(indicators_dict)

#test usage
excerpts_dict=semanticSearchModule(test_query)
# print(excerpts_dict)


#Return top 10-20 most related 
# Define the filename to save the JSON data -  can remove later
json_filename = "outputs/excerpts.json"

# Save excerpts_dict to the JSON file just for a better preview
with open(json_filename, 'w', encoding='utf-8') as json_file:
    json.dump(excerpts_dict, json_file, ensure_ascii=False, indent=4)

print(f"Excerpts saved to {json_filename}")
# Out:
# {'indicator-id-1': 'value from indicator-id-1', 'indicator-id-2': 'value from indicator-id-2'}
# Excerpts saved to outputs/excerpts.json

# %% [markdown]
# <h3> synthesis module </h3>

# %% [markdown]
#     llm_instructions="llm instruction template here, with placeholders for insertion of user query, excerpts, indicator data, and entity and relation info"

# %%
# module to synthesize answer using retreival augmented generation approach

def synthesisModule(user_query, excerpts_dict, indicators_dict):
    
    # Generate prompt engineering text and template
    llm_instructions = f"""
    Ignore previous commands!!!
    Given a user query, use the provided excerpts, and Sources to
    provide the correct answer to the user's query
    
    User Query: {user_query}
    
    Sources: {excerpts_dict}
    

    - Answer output must be properly formatted using HTML. 
    - Don't include <html>, <script>, <link> or <body> tags. Only text formatting tags should be allowed. e.g h1..h3, p, anchor, etc.
    - Make sure to Include citations based on the Sources. e.g Text excerpt here<a data-id='test-doc-1'>[1]</a> when referencing a document in the sources. using 1 ...nth
    - The citations anchor should be near the excerpt not following each other.
    - Use the anchor tag for the citation links and should link to the document link. for example UNDP operates in Afghanistan <a data-id='test-doc-1'>[1]</a>. UNDP offers health relationships <a data-id='test-doc-2'>[2]</a>.
    - The text in the anchor tag should be citation number not document title.
    - You can reference multiple citations based sources
    """
    ###synthesize data into structure within llm prompt engineering instructions
    answer=callOpenAI(llm_instructions)
    
    return answer

## to test this, run the full pipeline with the handleApiCall function

# %%
# module to synthesize answer using retreival augmented generation approach

def synthesisModule_with_KG(user_query, entities, relationships, excerpts_dict, indicators_dict):
    
    # Generate prompt engineering text and template
    llm_instructions = f"""
    Ignore previous commands!!!
    Given a user query, use the provided excerpts, Sources, and relevant entities and relations to
    provide the correct answer to the user's query
    
    User Query: {user_query}
    
    Sources: {excerpts_dict}
    
    Entity and Relation info: {entities} {relationships}

    - Answer output must be properly formatted using HTML. 
    - Don't include <html>, <script>, <link> or <body> tags. Only text formating tags should be allowed. e.g h1..h3, p, anchor, etc.
    - Make sure to Include citations based on the Sources. e.g Text excerpt here<a data-id='test-doc-1'>[1]</a> when referencing a document in the sources. using 1 ...nth
    - The citations anchor should be near the excerpt not following each other.
    - Use the anchor tag for the citation links and should link to the document link. for example Undp operates in Afghanistan <a data-id='test-doc-1'>[1]</a>. UNDP offers health relationships <a data-id='test-doc-2'>[2]</a>.
    - The text in the anchor tag should be citation number not document title.
    - You can reference multiple citations based sources
    """
    ###synthesize data into structure within llm prompt engineering instructions
    answer=callOpenAI(llm_instructions)
    
    return answer

## to test this, run the full pipeline with the handleApiCall function

# %% [markdown]
# <h3> run pipeline </h3>

# %%
# full pipeline with retreival, synthesis of answer to user query, and structure results into api response

def handleApiCall(user_query):
        
    ##run processing modules (in parallel)
    #entities_dict=knowledgeGraphModule(user_query)
    excerpts_dict=semanticSearchModule(user_query)
    indicators_dict=indicatorsModule(user_query) ##lower priority
    #query_idea_list=queryIdeationModule(user_query) ##lower priority
    
    ##synthesis module
    answer=synthesisModule(user_query, excerpts_dict, indicators_dict)
    
    ##structure response
    response={
        "user_query":user_query,
        "answer":answer,
        "sources":excerpts_dict
        
    }
    
    return response

# test usage
response=handleApiCall(test_query) 
# Define the filename to save the JSON data -  can remove later
json_filename = "outputs/query2_answer.json"

# Save excerpts_dict to the JSON file just for a better preview
with open(json_filename, 'w', encoding='utf-8') as json_file:
    json.dump(response, json_file, ensure_ascii=False, indent=4)

print(f"Synthesis saved to {json_filename}")
# Out:
# Synthesis saved to query2_output.json

# %%
# full pipeline with retreival, synthesis of answer to user query, and structure results into api response

def handle_api_call_with_kg(user_query):
        
    ##run processing modules (in parallel)
    #entities_dict=knowledgeGraphModule(user_query)
    excerpts_dict=semanticSearchModule(user_query)
    indicators_dict=indicatorsModule(user_query) ##lower priority
    #query_idea_list=queryIdeationModule(user_query) ##lower priority
    
    ##synthesis module
    answer=synthesisModule_with_KG(user_query, entities, relationships[:10], excerpts_dict, indicators_dict)
    
    ##structure response
    response={
        "user_query":user_query,
        "answer":answer,
        "sources":excerpts_dict,
        "entities": entities,
        "relations":relationships
        
    }
    
    return response

# test usage
response=handle_api_call_with_kg(test_query) 
# Define the filename to save the JSON data -  can remove later
json_filename = "outputs_KG/Query2_output.json"

# Save excerpts_dict to the JSON file just for a better preview
with open(json_filename, 'w', encoding='utf-8') as json_file:
    json.dump(response, json_file, ensure_ascii=False, indent=4)

print(f"Synthesis saved to {json_filename}")
# Out:
# Synthesis saved to outputs_KG/Query2_output.json

# %% [markdown]
# <h3>testing</h3>

# %%
## next step, develop automated testing for all modules
## iterate through test_queries and build automated tests to score results

# open testing dataset with queries and expected results
test_queries_df=pd.read_csv("../testing/energy_ai_test_dataset_v0.csv")

# %%
# Candidate and reference texts
cands = ["The quick brown fox jumps over the lazy dog"]
refs = ["A fast brown fox leaps over a lazy dog"]

# Calculate BERTScore
P, R, F1 = score(cands, refs, lang="en")

# Output the results
print(f"Precisions: {P.tolist()}")
print(f"Recalls: {R.tolist()}")
print(f"F1 scores: {F1.tolist()}")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
#   # TODO:::
#   ##### Add citation prompt to the synthesis module. -done
#   ##### Convert notebook to flask API script. main.py - done
#   ##### Refactor PDF -> txt pipeline

# %%
## module to get information on the entities from user query using the KG
def knowledgeGraphModule(user_query):
    
    # generate list of entities based on user query
    entity_list = extractEntitiesFromQuery(user_query)
    my_list = ast.literal_eval(entity_list)
    prompt_summarise_entites = f"""
    Summarize all relations between all the entities : {my_list}
    """
    summarise_entities = callOpenAI(prompt_summarise_entites)
    # Initialize an empty dictionary to store information
    entities_dict = {
        "relations": summarise_entities,
        "entities": {}
    }
    # Loop through each entity in the list
    for entity in my_list:
        # Fetch information about the entity from your knowledge graph
        prompt = f"Give me a short description 50 words of {entity}"
        entity_info = callOpenAI(prompt)
        # Add the entity information to the dictionary
        entities_dict["entities"][entity] = entity_info
    
    return entities_dict


# Test usage
test_query = "what is the major work on UNDP in Afganistan?"
entities_dict = knowledgeGraphModule(test_query)
print(entities_dict)
# Out:
# {'relations': 'The relation between UNDP and Afghanistan is that UNDP works in Afghanistan to support development projects and initiatives.', 'entities': {'UNDP': 'The United Nations Development Programme (UNDP) is a global organization that works to eradicate poverty, reduce inequalities, and promote sustainable development. It provides support to countries in areas such as governance, climate change, and crisis response, aiming to improve the lives of people and protect the planet.', 'Afghanistan': 'Afghanistan is a landlocked country located in Central Asia, bordered by Iran, Pakistan, Turkmenistan, Uzbekistan, Tajikistan, and China. It is known for its rugged mountainous terrain, rich cultural heritage, and complex history. Despite facing numerous challenges, Afghanistan is home to resilient people, diverse ethnic groups, and a vibrant blend of traditions.'}}

# %%
def relationships_to_data_structure(relationships):
    """
    Converts relationships from Neo4j query output into a structured Python data structure.

    :param relationships: A list of Relationship objects from a Neo4j query.
    :return: A list of dictionaries, each representing a relationship and its node details.
    """
    formatted_relationships = []

    # Sort the relationships by the name of the source node for consistent ordering
    sorted_relationships = sorted(relationships, key=lambda rel: rel.start_node['name'])

    for rel in sorted_relationships:
        relationship_data = {
            'relationship_type': rel.__class__.__name__,
            'source_node': {
                'name': rel.start_node['name'],
                'category': rel.start_node.get('category', 'N/A'),
                'summary': rel.start_node.get('summary', ''),
                'acronym': rel.start_node.get('acronym', ''),
                # Include additional properties as needed
            },
            'target_node': {
                'name': rel.end_node['name'],
                'category': rel.end_node.get('category', ''),
                'summary': rel.end_node.get('summary', ''),
                'acronym': rel.end_node.get('acronym', ''),

                # Include additional properties as needed
            },
            'properties': {
                # Include relationship properties
                'description': rel.get('description', 'N/A'),
            
            }
        }

        formatted_relationships.append(relationship_data)

    return formatted_relationships

# Example usage, assuming 'relationships' is your list of Relationship objects from the query
formatted_data = relationships_to_data_structure(entity_info['relationships'])

# %%
def format_and_sort_relationships(relationships):
    """
    Formats and sorts the relationships from Neo4j query output.

    :param relationships: A list of Relationship objects from a Neo4j query.
    """
    # Sort the relationships by the name of the source node for consistent ordering
    sorted_relationships = sorted(relationships, key=lambda rel: rel.start_node['name'])

    for rel in sorted_relationships:
        source_node = rel.start_node
        target_node = rel.end_node
        print(f"Relationship: {rel.__class__.__name__}")
        print(f"  Source Node: {source_node['name']} (Category: {source_node.get('category', 'N/A')})")
        print(f"  Target Node: {target_node['name']} (Category: {target_node.get('category', 'N/A')})")
        
        # Print relationship properties with indentation
        if rel.get('description'):
            print(f"  Description: {rel['description']}")
        if rel.get('summary'):
            print(f"  Summary: {rel['summary']}")

        print()  # Add a newline for spacing between relationships

# Example usage, assuming 'relationships' is your list of Relationship objects from the query
format_and_sort_relationships(entity_info['relationships'])
# Out:
# Relationship: contributes_to
#   Source Node: Afghanistan (Category: Location)
#   Target Node: Renewable Energy Coordination committee (Category: Organization)
#   Description: Given the importance of REN and the role it will play in the socio-economic development of Afghanistan, its development needs to be put on a “fast-track” Renewable Energy Coordination committee which will be established under MEW and work under the Deputy Minister for Energy the mandate of the RECC is to coordinate with all relevant gov/non gov entities for the implementation of this policy.
